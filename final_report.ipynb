# %%
install.packages(c(
  "rmarkdown",
  "knitr",
  "tidyverse",
  "ggplot2",
  "DT",
  "kableExtra",
  "tinytex"
), repos = "https://cloud.r-project.org")
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’, ‘svglite’

# %%
file.create("final_report.Rmd")
# Out:
# [1] TRUE

# %%
yaml_content <- '---
title: "Statistical Intelligence for Sports Performance & Business Strategy"
author: "Hepziba J"
date: "`r Sys.Date()`"
output:
  pdf_document:
    toc: true
    number_sections: true
---'

# Overwrite final_report.Rmd with the YAML header content
writeLines(yaml_content, "final_report.Rmd")

# %%
tinytex::install_tinytex(force = TRUE)
rmarkdown::render("final_report.Rmd")
# Out:
# Warning message in extract(pkg, exdir = path.expand(target)):
# “‘/bin/tar -xf 'TinyTeX-1.tar.gz' -C '/root'’ returned error code 2”
# tlmgr option sys_bin ~/bin
#
# tlmgr option repository 'https://mirror.clarkson.edu/ctan/systems/texlive/tlnet'
#
# tlmgr update --list
#
#
#
# processing file: final_report.Rmd
# 1/4
# 2/4 [setup]
# 3/4 [unnamed-chunk-1]
# 4/4
# output file: final_report.knit.md
# /usr/bin/pandoc +RTS -K512m -RTS final_report.knit.md --to latex --from markdown+autolink_bare_uris+tex_math_single_backslash --output final_report.tex --lua-filter /usr/lib/R/site-library/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /usr/lib/R/site-library/rmarkdown/rmarkdown/lua/latex-div.lua --self-contained --table-of-contents --toc-depth 2 --number-sections --highlight-style tango --pdf-engine pdflatex --variable graphics --variable 'geometry:margin=1in'
# Output created: final_report.pdf

# %%
r_chunk_content <- '```{r load-data}
matches <- read.csv("matches.csv")
head(matches)
```'

# Append the R chunk content to final_report.Rmd
write(r_chunk_content, file = "final_report.Rmd", append = TRUE)

# %%
rmarkdown::render("final_report.Rmd")
# Out:
# processing file: final_report.Rmd
# 1/3
# 2/3 [setup]
# 3/3
# output file: final_report.knit.md
# /usr/bin/pandoc +RTS -K512m -RTS final_report.knit.md --to latex --from markdown+autolink_bare_uris+tex_math_single_backslash --output final_report.tex --lua-filter /usr/lib/R/site-library/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /usr/lib/R/site-library/rmarkdown/rmarkdown/lua/latex-div.lua --self-contained --table-of-contents --toc-depth 2 --number-sections --highlight-style tango --pdf-engine pdflatex --variable graphics --variable 'geometry:margin=1in'
# Output created: final_report.pdf
